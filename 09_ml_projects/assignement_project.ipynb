# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from sklearn.metrics import precision_score, recall_score, accuracy_score

# %%
flower_df = pd.read_csv('iris.csv')

# %%
flower_df['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(x=flower_df['species'], y = flower_df['sepal_length'], marker="o")
plt.grid()

# %%
X = flower_df.drop("species", axis = 1)
y1 = flower_df['species']
y = y1.map({'Iris-setosa' : 0, 'Iris-versicolor':1, 'Iris-virginica':2})

# %%
y.sample(10)
# Out:
# 80     1
# 43     0
# 124    2
# 68     1
# 37     0
# 132    2
# 22     0
# 89     1
# 119    2
# 47     0
# Name: species, dtype: int64

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
# print(X_scaled)

# %%
# Train test split 
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size = 0.2, random_state = 42
)

# %%
logistic_model = LogisticRegression()
logistic_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logistic_model.predict(X_test)

print("accuracy score : ", accuracy_score(y_pred, y_test))
print("r2 score : ", r2_score(y_pred, y_test))
# Out:
# accuracy score :  0.9666666666666667
# r2 score :  0.9542682926829269

# %%
# Scale the all values 

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier = KNeighborsClassifier(n_neighbors=3)
knn_classifier.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn_classifier.predict(X_test_scaled)

print("Accuracy score : ", accuracy_score(y_pred, y_test))
print("Recall score : ", recall_score(y_test, y_pred, average='macro'))
print("Precision Score : ", precision_score(y_pred, y_test, average='macro'))
# Out:
# Accuracy score :  0.9666666666666667
# Recall score :  0.9696969696969697
# Precision Score :  0.9696969696969697

# %%
knn_classifier = KNeighborsClassifier(n_neighbors=5)
knn_classifier.fit(X_train_scaled, y_train)

y_pred = knn_classifier.predict(X_test_scaled)

print("Accuracy score : ", accuracy_score(y_pred, y_test))
print("Recall score : ", recall_score(y_test, y_pred, average='macro'))
print("Precision Score : ", precision_score(y_pred, y_test, average='macro'))
# Out:
# Accuracy score :  0.9666666666666667
# Recall score :  0.9696969696969697
# Precision Score :  0.9696969696969697

# %%
knn_classifier = KNeighborsClassifier(n_neighbors=7)
knn_classifier.fit(X_train_scaled, y_train)

y_pred = knn_classifier.predict(X_test_scaled)

print("Accuracy score : ", accuracy_score(y_pred, y_test))
print("Recall score : ", recall_score(y_test, y_pred, average='macro'))
print("Precision Score : ", precision_score(y_pred, y_test, average='macro'))
# Out:
# Accuracy score :  0.9666666666666667
# Recall score :  0.9696969696969697
# Precision Score :  0.9696969696969697

# %%
knn_classifier = KNeighborsClassifier(n_neighbors=9)
knn_classifier.fit(X_train_scaled, y_train)

y_pred = knn_classifier.predict(X_test_scaled)

print("Accuracy score : ", accuracy_score(y_pred, y_test))
print("Recall score : ", recall_score(y_test, y_pred, average='macro'))
print("Precision Score : ", precision_score(y_pred, y_test, average='macro'))
# Out:
# Accuracy score :  0.9666666666666667
# Recall score :  0.9696969696969697
# Precision Score :  0.9696969696969697

# %%
knn_classifier = KNeighborsClassifier(n_neighbors=11)
knn_classifier.fit(X_train_scaled, y_train)

y_pred = knn_classifier.predict(X_test_scaled)

# Print the all values that we want

print("Precision Score : ", precision_score(y_pred, y_test, average='macro'))
print("Accuracy Score : ", accuracy_score(y_pred, y_test))
print("recall Score : ", recall_score(y_pred, y_test, average='macro'))
# Out:
# Precision Score :  0.9696969696969697
# Accuracy Score :  0.9666666666666667
# recall Score :  0.9666666666666667

# %%
# Naive Bayes Use case 

from sklearn.naive_bayes import GaussianNB

gnb_model = GaussianNB()
gnb_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb_model.predict(X_test)

print("Precision Score : ", precision_score(y_pred, y_test, average='macro'))
print("Accuracy Score : ", accuracy_score(y_pred, y_test))
print("recall Score : ", recall_score(y_pred, y_test, average='macro'))
# Out:
# Precision Score :  1.0
# Accuracy Score :  1.0
# recall Score :  1.0
