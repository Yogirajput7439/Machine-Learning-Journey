# %%
import matplotlib.pyplot as plt

# %%
# Scatter Plots
people = ["Person A", "Person B", "Person C", "Person D", "Person E", 
          "Person F", "Person G", "Person H", "Person I", "Person J"]

age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
blood_pressure = [110, 115, 120, 122, 125, 130, 135, 123, 145, 150]

sizes = blood_pressure


colors = ["green" if x < 135 else "red" for x in (blood_pressure)]
plt.scatter(age, blood_pressure, color=colors, s=sizes, marker='o')
plt.title("Blood Pressure Age Wise")
plt.xlabel("Age")
plt.ylabel("Blood Pressure")
plt.grid(True)
plt.scatter(age, blood_pressure, c=blood_pressure, cmap="OrRd")
plt.colorbar(label="BP")

# %%
# Multiple scatter plots
cities = ["City A", "City B", "City C", "City D", "City E"]

# Winter: Temperature (°C) vs Humidity (%)
winter_temp = [5, 2, 10, 0, 7]
winter_humidity = [80, 75, 65, 85, 70]

# Summer: Temperature (°C) vs Humidity (%)
summer_temp = [25, 30, 28, 35, 27]
summer_humidity = [60, 50, 55, 45, 65]

plt.scatter(winter_temp, winter_humidity, label="Winter")
plt.scatter(summer_temp, summer_humidity, label="Summer")
plt.title("Summer vs Winter Temp and Humidity")
plt.xlabel("Temperature in (°C) ")
plt.ylabel("Humidity in (%)")
plt.grid()
plt.legend()
plt.tight_layout()

# %%
# Pie Charts
expenses = ["Salaries", "Rent", "Marketing", "R&D", "Miscellaneous"]
amounts = [500, 150, 120, 100, 50]

# data = list(zip(values, labels))
# data.sort(reverse=True)   # bada → chhota

# values_sorted, labels_sorted = zip(*data)

data = list(zip(amounts, expenses))
data.sort(reverse=False)
sorted_amounts, sorted_expenses =zip(*data)

explode = (0, 0, 0, 0, 0)
plt.pie(sorted_amounts, labels=sorted_expenses, explode=explode, autopct='%1.1f%%', startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x11634b6b0>,
#   <matplotlib.patches.Wedge at 0x1161b6c90>,
#   <matplotlib.patches.Wedge at 0x11634bec0>,
#   <matplotlib.patches.Wedge at 0x11638c470>,
#   <matplotlib.patches.Wedge at 0x11638ca70>],
#  [Text(-0.1869014174640818, 1.0840054705350508, 'Miscellaneous'),
#   Text(-0.6941967196545119, 0.8532824353172372, 'R&D'),
#   Text(-1.0897545349999864, 0.14978335503974946, 'Marketing'),
#   Text(-0.777817477511334, -0.7778174410990703, 'Rent'),
#   Text(1.0897545349999864, -0.14978335503974957, 'Salaries')],
#  [Text(-0.10194622770768096, 0.5912757112009368, '5.4%'),
#   Text(-0.3786527561751883, 0.46542678290031114, '10.9%'),
#   Text(-0.5944115645454471, 0.08170001183986333, '13.0%'),
#   Text(-0.4242640786425458, -0.424264058781311, '16.3%'),
#   Text(0.5944115645454471, -0.0817000118398634, '54.3%')])
